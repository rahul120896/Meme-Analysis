# %%
from PIL import Image
import pytesseract as tess
import os

# %%
tess.pytesseract.tesseract_cmd = r'C:\Users\student\AppData\Local\Tesseract-OCR\tesseract.exe'

# %%
img = Image.open('Dataset/626.jpg')
text = tess.image_to_string(img)
print(text)
# Out:
# min the GD program Your Hono

# %%
os.listdir('Dataset/')
# Out:
# ['0.jpg',
#  '1.jpg',
#  '10.jpg',
#  '100.jpg',
#  '101.jpg',
#  '102.jpg',
#  '103.jpg',
#  '104.jpg',
#  '105.jpg',
#  '106.jpg',
#  '107.jpg',
#  '108.jpg',
#  '109.jpg',
#  '11.jpg',
#  '110.jpg',
#  '111.jpg',
#  '112.jpg',
#  '113.jpg',
#  '114.jpg',
#  '115.jpg',
#  '116.jpg',
#  '117.jpg',
#  '118.jpg',
#  '119.jpg',
#  '12.jpg',
#  '120.jpg',
#  '121.jpg',
#  '122.jpg',
#  '123.jpg',
#  '124.jpg',
#  '125.jpg',
#  '127.jpg',
#  '128.jpg',
#  '129.jpg',
#  '13.jpg',
#  '130.jpg',
#  '131.jpg',
#  '134.jpg',
#  '135.jpg',
#  '136.jpg',
#  '137.jpg',
#  '138.jpg',
#  '139.jpg',
#  '14.jpg',
#  '140.jpg',
#  '141.jpg',
#  '142.jpg',
#  '143.jpg',
#  '144.jpg',
#  '145.jpg',
#  '146.jpg',
#  '147.jpg',
#  '148.jpg',
#  '149.jpg',
#  '15.jpg',
#  '151.jpg',
#  '152.jpg',
#  '153.jpg',
#  '154.jpg',
#  '155.jpg',
#  '156.jpg',
#  '157.jpg',
#  '158.jpg',
#  '159.jpg',
#  '16.jpg',
#  '160.jpg',
#  '161.jpg',
#  '162.jpg',
#  '163.jpg',
#  '164.jpg',
#  '165.jpg',
#  '166.jpg',
# ...

# %%
for items in os.listdir('Dataset/'):
    image='Dataset\\'+items
    img=Image.open(image)
    text=tess.image_to_string(img)
    print(text)
# Out:
# corer i A i
# 1 4 best el
#
# Youli(i/') Channels to follow
# rl ,
#
# Li 000 Le
# Sy _infoqtestbytesnet
# 99 little bugs in the code.
# » 99 little bugs in the code.
# Take one down, patch it around.
#
#
#
# \
#
# ‘ 127 little bugs in the code...
# Bulle SEES CH
# how it actually works.
# .
# ,*
# “
#
# =
# SC ae
#
#
#
#
#
# a Se
# Pw
#
# SUR EDD ate 3
#
#
#
# Ley. y
# or \ a
# WHAT YOU NEED
# TO KNOW!
# 7
#
# aa
# “=
# ‘a
#
# CE e
# testbytes
#
# Making Quaity 2 Habit
#
# f
#
# Da]
# Useful
# Ghrome Extensions
#
# Software Testers
#
# info@testbytes.het
#
# BOLDSTEXTIUSING HTML
#
#
#
#
#
#
#
#
#
# WF
# ULC AULa
# PROGRAMMER!
#
#
# a Se
# Pw
#
# SUR EDD ate 3
#
#
# @ vey
#
# OGz==2
#
# © end me pussy pies
# a
#
# .
# (( ))
#
# BUG FEATURE
# fone
#
# i _ if = —
# poner COR SmeT Re ESeCA Imocicnan | Gener) COR Seer me Rta Iya pune © & “Sul Sul 90% MM 5:37 pr
#
#
#
#
#
# Avoid blocking your Chip from spam... CHOOSE A FILE
#
# Pause for 3 seconds Hey There, This is the dummy
# ...
